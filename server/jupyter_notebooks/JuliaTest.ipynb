# %%
using Pkg
Pkg.clone("https://github.com/shashi/WebIO.jl.git")
# Pkg.build("WebIO") # this will set up the IJulia server plugin
# Out:
#   Updating git-repo `https://github.com/shashi/WebIO.jl.git`
#  Resolving package versions...
# ┌ Info: Path `/home/server/.julia/dev/WebIO` exists and looks like the correct package, using existing path instead of cloning
# └ @ Pkg.Types /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.0/Pkg/src/Types.jl:588
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
cd(Pkg.dir("WebIO", "webio"))
;jupyter labextension install webio
;jupyter labextension enable webio/jupyterlab_entry
# Out:
# IOError: chdir /home/server/.julia/dev/WebIO/webio: no such file or directory (ENOENT)
#
# Stacktrace:
#  [1] uv_error at ./libuv.jl:85 [inlined]
#  [2] cd(::String) at ./file.jl:76
#  [3] top-level scope at In[13]:1

# %%
using Plots, ProgressMeter
pyplot()
plot(Plots.fakedata(50, 5), w=3)

# %%
2+2
# Out:
# 4
