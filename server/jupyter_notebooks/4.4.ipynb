# %% [markdown]
# # $(-1-\sqrt{\frac{281}{25}})/2(\frac{-8}{625})$
#
# Expression:
#
# $(-1-\sqrt{\frac{281}{25}})/2(\frac{-8}{625})$
#
# Parentheses (really just PEMDAS recursively through every expression within parentheses):
#
# $-4.352610922848042 / 2*-0.0128$
#
# Multiplication
#
# $(-4.352610922848042 / 2)*(-0.0128)$
#
# Division
#
# $-2.176305461424021 * -0.0128$
#
# 0.02785670990622747

# %%
-8/625
# Out:
# -0.0128

# %%
from math import sqrt

(-1-sqrt(281/25))/2
# Out:
# -2.176305461424021

# %%
-4.352610922848042 / 2
# Out:
# -2.176305461424021

# %%
-2.176305461424021 * -0.0128
# Out:
# 0.02785670990622747

# %%
from sympy import Rational

Rational(_)
# Out:
# 4014574987310529/144115188075855872

# %% [markdown]
# ## Quadratic troubleshooter

# %%
from fractions import Fraction

# %%
a = Rational(-8, 625)
b = 1
c = 100

# %% [markdown]
# Roots (if real):

# %%
discriminant = (b**2)-4*a*c
a_two = 2*a

((-b+sqrt(discriminant))/a_two, (-b-sqrt(discriminant))/a_two)
# Out:
# (-57.5727881004139, 135.697788100414)

# %%
float(-4*a*c)
# Out:
# 5.12

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# min_x = -50;
# max_x = 5;

# expr = 2*x**2+2*x+2

# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
# x = np.linspace(min_x,max_x,100)

# ax.spines['left'].set_position('center')
# ax.spines['bottom'].set_position('center')
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.xaxis.set_ticks_position('bottom')
# ax.yaxis.set_ticks_position('left')
# plt.plot(x, expr, ':b', label='y=2x+1')
# plt.legend(loc='upper left')
# plt.show()

# %% [markdown]
# ## Exploration of Simpson's Rule
#
# Or this tiny application of it, anyway

# %%
from __future__ import print_function
from sympy import nonlinsolve, linsolve, symbols, latex, expr

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

def f(x):
    return x**2+3*x+5

p0 = (-4, f(-4))
p1 = (0, f(0))
p2 = (4, f(4))

areaExpr = ((p2[0]-p0[0])/6)*(p0[1]+4*p1[1]+p2[1])

a, b, c, x = symbols('a b c x')

def quadSub(x, y):
    return a*x**2+b*x+c-y

soe = [
    quadSub(p0[0], p0[1]),
    quadSub(p1[0], p1[1]),
    quadSub(p2[0], p2[1]),
]

solved = nonlinsolve(soe, [a, b, c])

solvedCoefficients = tuple(*solved)

import matplotlib.pyplot as plt
import numpy as np

padding = 2;

min_x = p0[0] - padding;
max_x = p2[0] + padding;

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.linspace(min_x,max_x,100)

a, b, c = solvedCoefficients

expr = a*x**2+b*x+c

def eval_expr(x):
    return float(a)*x**2+float(b)*x+float(c)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.plot(x, expr, ':b', label=f'${a}x^2 + {b}x + {c}$')
plt.plot(p0[0], p0[1], 'o')
plt.plot(p1[0], p1[1], 'o')
plt.plot(p2[0], p2[1], 'o')
section = np.arange(p0[0], p2[0], 1/50.)
plt.fill_between(section, 0, eval_expr(section), facecolor='blue', alpha=0.5)

plt.legend(loc='upper left')
plt.show()

(Fraction(areaExpr).limit_denominator(), p0[1], 4*p1[1], p2[1], p0[1]+4*p1[1]+ p2[1], Fraction((p2[0]-p0[0])/6).limit_denominator())
# Out:
# <img src="data:image/png;base64,..." width="640">
# (Fraction(248, 3), 9, 20, 33, 62, Fraction(4, 3))

# %%
import cmath

cmath.sqrt(-225)

Out[428]
# Out:
# 15j

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

import numpy as np

x = np.random.randn(2000)
y = np.random.randn(2000)

plot([go.Histogram2dContour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# 'temp-plot.html'

# %%
from IPython.display import display, Markdown, Latex

display(Latex('$abcdefgpieiklmnohijklmno$'))
# Out:
# $abcdefgpieiklmnohijklmno$
